# %%
from utils import *

# %% [markdown]
# #### Forest Control Run

# %%
orig_path = "../wrfxpy/wksp/wfc-forest-control-2024-10-27_16:00:00-13/wrf/wrfout_d03_2024-10-28_05:00:00"
ctrl_path = "../wrfxpy/wksp/wfc-forest-control-2024-10-27_16:00:00-13/wrf_exercise/wrfout_d03_2024-10-28_05:00:00"
plot_baseline_vs_control(orig_path, ctrl_path)
# Out:
# /home/afarguell/anaconda3/envs/rapids-23.12/lib/python3.10/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/afarguell/anaconda3/envs/rapids-23.12/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float32'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# /home/afarguell/anaconda3/envs/rapids-23.12/lib/python3.10/site-packages/numpy/core/getlimits.py:518: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   setattr(self, word, getattr(machar, word).flat[0])
# /home/afarguell/anaconda3/envs/rapids-23.12/lib/python3.10/site-packages/numpy/core/getlimits.py:89: UserWarning: The value of the smallest subnormal for <class 'numpy.float64'> type is zero.
#   return self._float_to_str(self.smallest_subnormal)
# ...

# %% [markdown]
# #### Forest Ensembles

# %%
ens_base_path = "/home/afarguell/wrfxpy_release/wksp/wfc-forest-control-2024-10-27_16:00:00-13/wrf_ens"
perturb_vars = ["fmc", "fuel load", "wind u", "wind v"]
data = process_ensemble(ens_base_path, perturb_vars)
plot_perturbations(data["MEMBERS"])
plot_fire_isochrones(data)
plot_fire_prob(data)
# Out:
# Processing ensemble ens_000
# Processing ensemble ens_001
# /fs/ember-fs2/adata/afarguell/wildfire_risk_modeling_exercise/SUBMISSION/postproc/utils.py:59: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   srx = int(ds.dims["west_east_subgrid"]/(ds.dims["west_east"]+1))
# /fs/ember-fs2/adata/afarguell/wildfire_risk_modeling_exercise/SUBMISSION/postproc/utils.py:60: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   sry = int(ds.dims["south_north_subgrid"]/(ds.dims["south_north"]+1))
# Processing ensemble ens_002
# Processing ensemble ens_003
# Processing ensemble ens_004
# ...

# %% [markdown]
# #### Prairie Control Run

# %%
orig_path = "../wrfxpy/wksp/wfc-prairie-control-2026-03-09_14:00:00-13/wrf/wrfout_d03_2026-03-10_03:00:00"
ctrl_path = "../wrfxpy/wksp/wfc-prairie-control-2026-03-09_14:00:00-13/wrf_exercise/wrfout_d03_2026-03-10_03:00:00"
plot_baseline_vs_control(orig_path, ctrl_path)
# Out:
# /fs/ember-fs2/adata/afarguell/wildfire_risk_modeling_exercise/SUBMISSION/postproc/utils.py:95: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   srx = int(ctrl_ds.dims["west_east_subgrid"]/(ctrl_ds.dims["west_east"]+1))
# /fs/ember-fs2/adata/afarguell/wildfire_risk_modeling_exercise/SUBMISSION/postproc/utils.py:96: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   sry = int(ctrl_ds.dims["south_north_subgrid"]/(ctrl_ds.dims["south_north"]+1))
# ...

# %% [markdown]
# #### Prairie Ensembles

# %%
ens_base_path = "../wrfxpy/wksp/wfc-prairie-control-2026-03-09_14:00:00-13/wrf_ens"
perturb_vars = ["fmc", "fuel load", "wind u", "wind v"]
data = process_ensemble(ens_base_path, perturb_vars)
plot_perturbations(data["MEMBERS"])
plot_fire_isochrones(data)
plot_fire_prob(data)
# Out:
# Processing ensemble ens_000
# Processing ensemble ens_001
# /fs/ember-fs2/adata/afarguell/wildfire_risk_modeling_exercise/SUBMISSION/postproc/utils.py:59: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   srx = int(ds.dims["west_east_subgrid"]/(ds.dims["west_east"]+1))
# /fs/ember-fs2/adata/afarguell/wildfire_risk_modeling_exercise/SUBMISSION/postproc/utils.py:60: FutureWarning: The return type of `Dataset.dims` will be changed to return a set of dimension names in future, in order to be more consistent with `DataArray.dims`. To access a mapping from dimension names to lengths, please use `Dataset.sizes`.
#   sry = int(ds.dims["south_north_subgrid"]/(ds.dims["south_north"]+1))
# Processing ensemble ens_002
# Processing ensemble ens_003
# Processing ensemble ens_004
# ...
